# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # __Objectives__

# %% [markdown]
# 1. What is Data science
# 2. Different ools used in Data science
# 3. Version control with Git
#
# - List popular languages for Data Science
# - Simple arithmetic expression to mutiply then add integers
# - Commonly used libraries used by Data Scientists

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. R
# 2. Python
# 3. Java

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. NumPy – For numerical computations and working with arrays.
#
# 2. Pandas – For data manipulation, cleaning, and analysis.
#
# 3. Matplotlib – For basic 2D visualizations (plots, charts, histograms).
#
# 4. Seaborn – Built on Matplotlib, for advanced statistical visualizations

# %% [markdown]
# ###  Data Science tools

# %% [markdown]
# |Data Science Tools|
# | ---------------- |
# | Spyder |
# | Jupyter Notebook / JupyterLab |
# |RStudio |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Charity Orhoridiohwo
